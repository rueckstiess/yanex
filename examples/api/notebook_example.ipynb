# %%
import yanex.results as yr

# get completed experiments with a limit of 10
experiments = yr.get_experiments(limit=10, status="completed")

# print the results in a readable format
for experiment in experiments:
    print(f"Experiment ID: {experiment.id}")
    print(f"Name: {experiment.name}")
    print(f"Description: {experiment.description}")
    print(f"Status: {experiment.status}")
    print(f"Started At: {experiment.started_at}")
    print(f"Completed At: {experiment.completed_at}")
    print(f"Params: {experiment.get_params()}")
    print(f"Metrics: {experiment.get_metrics()}")
    print("-" * 40)
# Out:
# Experiment ID: a522451b
# Name: foo
# Description: Testing experiment harness for mindexer experiments
# Status: completed
# Started At: 2025-07-19 02:11:32.299452+00:00
# Completed At: 2025-07-19 02:12:13.499290+00:00
# Params: {'eval': {'discard_best_worst': False, 'num_runs': 1}, 'mindexer': {'max_indexes': 0, 'sample_ratio': 0.01, 'verbose': True}, 'recommender': 'mindexer', 'slowms': 0, 'uri': 'mongodb://localhost:27017', 'workload': 'test', 'workload_params': {'ember': {'bar': False, 'foo': 1}, 'linkbench': {'num_queries': 1000, 'num_readers': 10, 'num_writers': 10, 'num_writes': 1000}, 'test': {'bar': 42, 'foo': 'test'}}}
# ...

# %%
experiments[0].get_metric("exec_time_no_indexes")
# Out:
# 4.529748874949291

# %%
yr.find(status="staged")
# Out:
# [{'completed_at': None,
#   'created_at': '2025-07-19T10:48:24.942546',
#   'description': None,
#   'duration': None,
#   'environment': {'capture_timestamp': None,
#    'dependencies': {'environment_yml': None,
# ...
